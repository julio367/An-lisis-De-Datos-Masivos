# %% [markdown]
# # ![](logo-itd.png)
#
# <div style = " Text-align: center">
#
# # Analisis de Datos Masivos
#
# ## Introduccion a las series en pandas
#
# ### Rodriguez Rivas Jose Gabriel
#
# ### Rubio Covarrubias Julio
#
# </div>

# %% [markdown]
# ## Tabla de Contenido
#
# [1-. Introduccion a **Dataframes** en Pandas](#id1)<br>
# [2-. Indexing Dataframes](#id2)<br>
# [3-. Transpuesta de un Dataframes](#id3)<br>
# [4-. Copiar Dataframes](#id4)<br>
# [5-. Loading CSV](#id5)<br>
# [6-. Busquedas en Dataframe](#id6)<br>
# [7-. Group by](#id7)<br>

# %% [markdown]
# ## Introduccion a Dataframes en Pandas <a id='id1'> </a>

# %%
import pandas as pd

# %%
Alumno1 = pd.Series({'Nombre' : 'Juan',
                    'Fecha Nacimiento' : '10-05-2000',
                    'Carrera' : 'IINF',
                    'Edad' : 20})
Alumno2 = pd.Series({'Nombre' : 'Karla',
                    'Fecha Nacimiento' : '10-02-2001',
                    'Carrera' : 'ISIC',
                    'Edad' : 19})
Alumno3 = pd.Series({'Nombre' : 'Pedro',
                    'Fecha Nacimiento' : '18-11-1998',
                    'Carrera' : 'IINF',
                    'Edad' : 22})
Alumno4 = pd.Series({'Nombre' : 'Maria',
                    'Fecha Nacimiento' : '15-09-1999',
                    'Carrera' : 'IINF',
                    'Edad' : 21})

# %%
Alumno1
# Out:
# Nombre                    Juan
# Fecha Nacimiento    10-05-2000
# Carrera                   IINF
# Edad                        20
# dtype: object

# %%
Alumnos = pd.DataFrame([Alumno1,Alumno2,Alumno3,Alumno4])
Alumnos
# Out:
#   Nombre Fecha Nacimiento Carrera  Edad
# 0   Juan       10-05-2000    IINF    20
# 1  Karla       10-02-2001    ISIC    19
# 2  Pedro       18-11-1998    IINF    22
# 3  Maria       15-09-1999    IINF    21

# %%
Alumnos.iloc[1]
# Out:
# Nombre                   Karla
# Fecha Nacimiento    10-02-2001
# Carrera                   ISIC
# Edad                        19
# Name: 1, dtype: object

# %% [markdown]
# ## Indexing Dataframes <a id='id2'> </a>

# %%
Alumnos = Alumnos.set_index('Carrera')
Alumnos
# Out:
#         Nombre Fecha Nacimiento  Edad
# Carrera
# IINF      Juan       10-05-2000    20
# ISIC     Karla       10-02-2001    19
# IINF     Pedro       18-11-1998    22
# IINF     Maria       15-09-1999    21

# %%
Alumnos.loc["IINF"]
# Out:
#         Nombre Fecha Nacimiento  Edad
# Carrera
# IINF      Juan       10-05-2000    20
# IINF     Pedro       18-11-1998    22
# IINF     Maria       15-09-1999    21

# %%
Alumnos.loc['IINF','Nombre']
# Out:
# Carrera
# IINF     Juan
# IINF    Pedro
# IINF    Maria
# Name: Nombre, dtype: object

# %%
Alumnos.loc['IINF',['Nombre','Edad']]
# Out:
#         Nombre  Edad
# Carrera
# IINF      Juan    20
# IINF     Pedro    22
# IINF     Maria    21

# %% [markdown]
# ## Transpuesta de un Dataframe <a id='id3'> </a>

# %%
Alumnos
# Out:
#         Nombre Fecha Nacimiento  Edad
# Carrera
# IINF      Juan       10-05-2000    20
# ISIC     Karla       10-02-2001    19
# IINF     Pedro       18-11-1998    22
# IINF     Maria       15-09-1999    21

# %%
Alumnos.T
# Out:
# Carrera                 IINF        ISIC        IINF        IINF
# Nombre                  Juan       Karla       Pedro       Maria
# Fecha Nacimiento  10-05-2000  10-02-2001  18-11-1998  15-09-1999
# Edad                      20          19          22          21

# %%
#Cambiar nuevamente el indice, pero para no perder la columna de
#carrera que esta como indice, lo pasamos a columna primero
#antes de crear el nuevo indice
Alumnos['Carrera'] = Alumnos.index
Alumnos = Alumnos.set_index('Nombre')
Alumnos
# Out:
#        Fecha Nacimiento  Edad Carrera
# Nombre
# Juan         10-05-2000    20    IINF
# Karla        10-02-2001    19    ISIC
# Pedro        18-11-1998    22    IINF
# Maria        15-09-1999    21    IINF

# %%
Alumnos = Alumnos.reset_index()
Alumnos
# Out:
#   Nombre Fecha Nacimiento  Edad Carrera
# 0   Juan       10-05-2000    20    IINF
# 1  Karla       10-02-2001    19    ISIC
# 2  Pedro       18-11-1998    22    IINF
# 3  Maria       15-09-1999    21    IINF

# %% [markdown]
# ## Copiar dataframes <a id='id4'> </a>

# %%
copia_Alumnos = Alumnos.copy()
copia_Alumnos
# Out:
#   Nombre Fecha Nacimiento  Edad Carrera
# 0   Juan       10-05-2000    20    IINF
# 1  Karla       10-02-2001    19    ISIC
# 2  Pedro       18-11-1998    22    IINF
# 3  Maria       15-09-1999    21    IINF

# %% [markdown]
# ## Loading CSV  as Dataframe <a id='id5'> </a>

# %%
df = pd.read_csv('olympics.csv')
df
# Out:
#                                                 0         1     2     3     4  \
# 0                                             NaN  № Summer  01 !  02 !  03 !
# 1                               Afghanistan (AFG)        13     0     0     2
# 2                                   Algeria (ALG)        12     5     2     8
# 3                                 Argentina (ARG)        23    18    24    28
# 4                                   Armenia (ARM)         5     1     2     9
# ..                                            ...       ...   ...   ...   ...
# 143  Independent Olympic Participants (IOP) [IOP]         1     0     1     2
# 144                            Zambia (ZAM) [ZAM]        12     0     1     1
# 145                          Zimbabwe (ZIM) [ZIM]        12     3     4     1
# 146                        Mixed team (ZZX) [ZZX]         3     8     5     4
# 147                                        Totals        27  4809  4775  5130
#
# ...

# %%
df.head()
# Out:
#                    0         1     2     3     4      5         6     7     8  \
# 0                NaN  № Summer  01 !  02 !  03 !  Total  № Winter  01 !  02 !
# 1  Afghanistan (AFG)        13     0     0     2      2         0     0     0
# 2      Algeria (ALG)        12     5     2     8     15         3     0     0
# 3    Argentina (ARG)        23    18    24    28     70        18     0     0
# 4      Armenia (ARM)         5     1     2     9     12         6     0     0
#
#       9     10       11    12    13    14              15
# 0  03 !  Total  № Games  01 !  02 !  03 !  Combined total
# 1     0      0       13     0     0     2               2
# 2     0      0       15     5     2     8              15
# 3     0      0       41    18    24    28              70
# 4     0      0       11     1     2     9              12

# %%
df = pd.read_csv('olympics.csv', index_col=0, skiprows=1)
df.head()
# Out:
#                          № Summer  01 !  02 !  03 !  Total  № Winter  01 !.1  \
# Afghanistan (AFG)              13     0     0     2      2         0       0
# Algeria (ALG)                  12     5     2     8     15         3       0
# Argentina (ARG)                23    18    24    28     70        18       0
# Armenia (ARM)                   5     1     2     9     12         6       0
# Australasia (ANZ) [ANZ]         2     3     4     5     12         0       0
#
#                          02 !.1  03 !.1  Total.1  № Games  01 !.2  02 !.2  \
# Afghanistan (AFG)             0       0        0       13       0       0
# Algeria (ALG)                 0       0        0       15       5       2
# Argentina (ARG)               0       0        0       41      18      24
# Armenia (ARM)                 0       0        0       11       1       2
# Australasia (ANZ) [ANZ]       0       0        0        2       3       4
#
#                          03 !.2  Combined total
# ...

# %%
df.columns
# Out:
# Index(['№ Summer', '01 !', '02 !', '03 !', 'Total', '№ Winter', '01 !.1',
#        '02 !.1', '03 !.1', 'Total.1', '№ Games', '01 !.2', '02 !.2', '03 !.2',
#        'Combined total'],
#       dtype='object')

# %%
for col in df.columns:
    if col [:2] =='01':
        df.rename(columns={col:'Gold' + col[4:]}, inplace=True)
    if col [:2] =='02':
        df.rename(columns={col:'Silver' + col[4:]}, inplace=True)
    if col [:2] =='03':
        df.rename(columns={col:'Bronze' + col[4:]}, inplace=True)
    if col [:1] =='№':
        df.rename(columns={col:'#' + col[1:]}, inplace=True)

# %%
df.head()
# Out:
#                          # Summer  Gold  Silver  Bronze  Total  # Winter  \
# Afghanistan (AFG)              13     0       0       2      2         0
# Algeria (ALG)                  12     5       2       8     15         3
# Argentina (ARG)                23    18      24      28     70        18
# Armenia (ARM)                   5     1       2       9     12         6
# Australasia (ANZ) [ANZ]         2     3       4       5     12         0
#
#                          Gold.1  Silver.1  Bronze.1  Total.1  # Games  Gold.2  \
# Afghanistan (AFG)             0         0         0        0       13       0
# Algeria (ALG)                 0         0         0        0       15       5
# Argentina (ARG)               0         0         0        0       41      18
# Armenia (ARM)                 0         0         0        0       11       1
# Australasia (ANZ) [ANZ]       0         0         0        0        2       3
#
# ...

# %% [markdown]
# ## Busquedas en Dataframes <a id='id6'> </a>

# %%
df['Gold'].head(10) > 0
# Out:
# Afghanistan (AFG)            False
# Algeria (ALG)                 True
# Argentina (ARG)               True
# Armenia (ARM)                 True
# Australasia (ANZ) [ANZ]       True
# Australia (AUS) [AUS] [Z]     True
# Austria (AUT)                 True
# Azerbaijan (AZE)              True
# Bahamas (BAH)                 True
# Bahrain (BRN)                False
# Name: Gold, dtype: bool

# %%
Ganadores_oro = df.where(df['Gold'] > 0)
Ganadores_oro
# Out:
#                                               # Summer    Gold  Silver  \
# Afghanistan (AFG)                                  NaN     NaN     NaN
# Algeria (ALG)                                     12.0     5.0     2.0
# Argentina (ARG)                                   23.0    18.0    24.0
# Armenia (ARM)                                      5.0     1.0     2.0
# Australasia (ANZ) [ANZ]                            2.0     3.0     4.0
# ...                                                ...     ...     ...
# Independent Olympic Participants (IOP) [IOP]       NaN     NaN     NaN
# Zambia (ZAM) [ZAM]                                 NaN     NaN     NaN
# Zimbabwe (ZIM) [ZIM]                              12.0     3.0     4.0
# Mixed team (ZZX) [ZZX]                             3.0     8.0     5.0
# Totals                                            27.0  4809.0  4775.0
#
#                                               Bronze    Total  # Winter  \
# ...

# %%
Ganadores_oro['Gold'].count()
# Out:
# 100

# %%
df['Gold'].count()
# Out:
# 147

# %%
Ganadores_oro = Ganadores_oro.dropna()
Ganadores_oro
# Out:
#                            # Summer    Gold  Silver  Bronze    Total  \
# Algeria (ALG)                  12.0     5.0     2.0     8.0     15.0
# Argentina (ARG)                23.0    18.0    24.0    28.0     70.0
# Armenia (ARM)                   5.0     1.0     2.0     9.0     12.0
# Australasia (ANZ) [ANZ]         2.0     3.0     4.0     5.0     12.0
# Australia (AUS) [AUS] [Z]      25.0   139.0   152.0   177.0    468.0
# ...                             ...     ...     ...     ...      ...
# Venezuela (VEN)                17.0     2.0     2.0     8.0     12.0
# Yugoslavia (YUG) [YUG]         16.0    26.0    29.0    28.0     83.0
# Zimbabwe (ZIM) [ZIM]           12.0     3.0     4.0     1.0      8.0
# Mixed team (ZZX) [ZZX]          3.0     8.0     5.0     4.0     17.0
# Totals                         27.0  4809.0  4775.0  5130.0  14714.0
#
#                            # Winter  Gold.1  Silver.1  Bronze.1  Total.1  \
# ...

# %%
Ganadores_oro2 = df[ df['Gold'] > 0]
Ganadores_oro2
# Out:
#                            # Summer  Gold  Silver  Bronze  Total  # Winter  \
# Algeria (ALG)                    12     5       2       8     15         3
# Argentina (ARG)                  23    18      24      28     70        18
# Armenia (ARM)                     5     1       2       9     12         6
# Australasia (ANZ) [ANZ]           2     3       4       5     12         0
# Australia (AUS) [AUS] [Z]        25   139     152     177    468        18
# ...                             ...   ...     ...     ...    ...       ...
# Venezuela (VEN)                  17     2       2       8     12         4
# Yugoslavia (YUG) [YUG]           16    26      29      28     83        14
# Zimbabwe (ZIM) [ZIM]             12     3       4       1      8         1
# Mixed team (ZZX) [ZZX]            3     8       5       4     17         0
# Totals                           27  4809    4775    5130  14714        22
#
# ...

# %%
Ganadores_oro = df.where(df['Gold'] > 0)
Ganadores_oro.dropna()
# Out:
#                            # Summer    Gold  Silver  Bronze    Total  \
# Algeria (ALG)                  12.0     5.0     2.0     8.0     15.0
# Argentina (ARG)                23.0    18.0    24.0    28.0     70.0
# Armenia (ARM)                   5.0     1.0     2.0     9.0     12.0
# Australasia (ANZ) [ANZ]         2.0     3.0     4.0     5.0     12.0
# Australia (AUS) [AUS] [Z]      25.0   139.0   152.0   177.0    468.0
# ...                             ...     ...     ...     ...      ...
# Venezuela (VEN)                17.0     2.0     2.0     8.0     12.0
# Yugoslavia (YUG) [YUG]         16.0    26.0    29.0    28.0     83.0
# Zimbabwe (ZIM) [ZIM]           12.0     3.0     4.0     1.0      8.0
# Mixed team (ZZX) [ZZX]          3.0     8.0     5.0     4.0     17.0
# Totals                         27.0  4809.0  4775.0  5130.0  14714.0
#
#                            # Winter  Gold.1  Silver.1  Bronze.1  Total.1  \
# ...

# %%
Ganadores_oro3 = df[ (df['Gold'] > 0) & (df['Gold.1'] > 0)]
Ganadores_oro3
# Out:
#                                      # Summer  Gold  Silver  Bronze  Total  \
# Australia (AUS) [AUS] [Z]                  25   139     152     177    468
# Austria (AUT)                              26    18      33      35     86
# Belarus (BLR)                               5    12      24      39     75
# Belgium (BEL)                              25    37      52      53    142
# Bulgaria (BUL) [H]                         19    51      85      78    214
# Canada (CAN)                               25    59      99     121    279
# China (CHN) [CHN]                           9   201     146     126    473
# Croatia (CRO)                               6     6       7      10     23
# Czech Republic (CZE) [CZE]                  5    14      15      15     44
# Czechoslovakia (TCH) [TCH]                 16    49      49      45    143
# Estonia (EST)                              11     9       9      15     33
# ...

# %%
Ganadores_oro3 = df[ (df['Gold'] > 0) | (df['Gold.1'] > 0)]
Ganadores_oro3
# Out:
#                            # Summer  Gold  Silver  Bronze  Total  # Winter  \
# Algeria (ALG)                    12     5       2       8     15         3
# Argentina (ARG)                  23    18      24      28     70        18
# Armenia (ARM)                     5     1       2       9     12         6
# Australasia (ANZ) [ANZ]           2     3       4       5     12         0
# Australia (AUS) [AUS] [Z]        25   139     152     177    468        18
# ...                             ...   ...     ...     ...    ...       ...
# Venezuela (VEN)                  17     2       2       8     12         4
# Yugoslavia (YUG) [YUG]           16    26      29      28     83        14
# Zimbabwe (ZIM) [ZIM]             12     3       4       1      8         1
# Mixed team (ZZX) [ZZX]            3     8       5       4     17         0
# Totals                           27  4809    4775    5130  14714        22
#
# ...

# %%
columnas = [
    '# Winter',
    'Gold.1',
    'Silver.1',
    'Bronze.1',
    'Total.1'
]
invierno = df[columnas]
invierno.head()
# Out:
#                          # Winter  Gold.1  Silver.1  Bronze.1  Total.1
# Afghanistan (AFG)               0       0         0         0        0
# Algeria (ALG)                   3       0         0         0        0
# Argentina (ARG)                18       0         0         0        0
# Armenia (ARM)                   6       0         0         0        0
# Australasia (ANZ) [ANZ]         0       0         0         0        0

# %% [markdown]
# ## Group by <a id='id7'> </a>
